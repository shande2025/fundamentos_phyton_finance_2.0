# %%
import pandas as pd

# Leemos el archivo CSV de Apple
df_apple = pd.read_csv('AAPL.csv')

# Mostramos las primeras 5 filas de las acciones
df_apple.head()
# Out:
#          Date   Adj Close       Close        High         Low        Open  \
# 0  2021-01-07  127.444359  130.919998  131.630005  127.860001  128.360001
# 1  2021-01-08  128.544373  132.050003  132.630005  130.229996  132.429993
# 2  2021-01-11  125.555862  128.979996  130.169998  128.500000  129.190002
# 3  2021-01-12  125.380676  128.800003  129.690002  126.860001  128.500000
# 4  2021-01-13  127.415138  130.889999  131.449997  128.490005  128.759995
#
#         Volume
# 0  109578200.0
# 1  105158200.0
# 2  100384500.0
# 3   91951100.0
# 4   88636800.0
